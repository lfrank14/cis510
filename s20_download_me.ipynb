# %% [markdown]
# #A test notebook
#
# Congrats. You have a jupter notebook running and it is hooked to Python.
#
# **Extra credit**. Click on the window (also called a cell) below then click the right pointing arrow. You will see a secret message printed.

# %%
print('Hello world')  #your first piece of Python code!
# Out:
# Hello world
