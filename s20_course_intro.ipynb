# %% [markdown]
# <center>
# <h1>Course Introduction</h1>
# </center>
#
# <hr>

# %% [markdown]
# #1. We are using zoom
# <img src='https://www.dropbox.com/s/9fcc1crlxp19ijt/major_section.png?raw=1' width='300'>
#
# First time for me using zoom for a course.  I want to spend some time now to go over zoom and its features.

# %% [markdown]
# #Stop!
# <img src='https://www.dropbox.com/s/kfnmns0f60q8b8z/red_line.png?raw=1' width='300'>
#
# Before doing anything else, what happens if zoom crashes? We need a plan.

# %% [markdown]
# ###The meeting url does not change during the quarter
#
# You can use the url that got you to this meeting to get to all future class meetings.
#
# * **If my zoom crashes**. I will immediately rejoin the meeting. I believe you are left in the meeting without me.
#
# * **If your zoom crashes**. Restart zoom and rejoin the meeting.

# %% [markdown]
# ##Let's go through some zoom features
#
# Note that I downloaded the zoom app and that is what I am using. Some documentation implied that using zoom through a web page did not give you all the features. So I downloaded the app.

# %% [markdown]
# #2. Audio and video
# <img src='https://www.dropbox.com/s/9fcc1crlxp19ijt/major_section.png?raw=1' width='300'>
#
# This is a tough one. The issue is some of you may have limted Internet bandwidth at home.
#
# I am going to suggest that you turn both audio and video off.
#
# I will leave audio on but turn video off.
#
# We can revisit this after we have held a couple  classes.

# %% [markdown]
# #3. How will we interact?
# <img src='https://www.dropbox.com/s/9fcc1crlxp19ijt/major_section.png?raw=1' width='300'>
#
# The class is based on interaction so important that we figure this out.

# %% [markdown]
# ##You can speak at any time
# <img src='https://www.dropbox.com/s/3uyvp722kp5to2r/assignment.png?raw=1' width='300'>
#
# If you are muted, you can unmute and speak.
#
# I set preferences so I can hit space bar to unmute as long as I am holding it down.
#
#  I'll do roll-call and we can test out your audio.
#
#  Say hi (or whatever you want) when I call on you.

# %% [markdown]
# ##You can raise your hand
# <img src='https://www.dropbox.com/s/3uyvp722kp5to2r/assignment.png?raw=1' width='300'>
#
# Everyone raise their hand please.
#
#  I believe it is in your Participants tab.

# %% [markdown]
# ##You can chat publically
# <img src='https://www.dropbox.com/s/3uyvp722kp5to2r/assignment.png?raw=1' width='300'>
#
# Go ahead and say hi publically.

# %% [markdown]
# ##You can chat privately
# <img src='https://www.dropbox.com/s/3uyvp722kp5to2r/assignment.png?raw=1' width='300'>
#
# Go ahead and tell me your favorite color privately.

# %% [markdown]
# #4. Screen sharing
# <img src='https://www.dropbox.com/s/9fcc1crlxp19ijt/major_section.png?raw=1' width='300'>
#
# I am sharing my screen with you right now! I have this open in a tab in Chrome. In fact it is a jupyter notebook. Check this out.

# %%
20 + 30 + 40
# Out:
# 90

# %% [markdown]
# ##I can give you permission to interact
#
# You can ask to take control of my screen. I could see using this to test your knowledge. Maybe ask one of you to fill in some Python code in my notebook. You will see what I mean later.

# %% [markdown]
# ##I can allow you to share your screen for the class
#
# I don't have a use for this yet but know that it is possible.

# %% [markdown]
# #5. One-on-one interaction
# <img src='https://www.dropbox.com/s/9fcc1crlxp19ijt/major_section.png?raw=1' width='300'>
#
# This is the tough one. In a normal class, I or the Learning Assistants would come to your table and work with you and others at your table. How can we do this in zoom?

# %% [markdown]
# ##Break out rooms
#
# I can create breakout rooms in zoom. They are inititally empty. Here is my idea. If you or a group of you wants to go over a problem, send me a private chat. I can then add you to a room and have someone (me, one of Learning Assistants) join you in the room.
#
# You can share your screen with just the members in the room and discuss by audio. You can stay in the room or go back to the main session.

# %% [markdown]
# ##Gotchas that I have noticed
#
# 1. You cannot enter a room on your own. I have to move you into it. You can leave the room on your own. However, it appears you may be able to re-enter a room on your own. So that is something.
#
# 2. There is no communication between those in breakout room and those in the main session. The exception is me (the host). You can ask me for help from a breakout room. I get a pop up. If I am busy, I click later. And then try to remember to get to you next.
#
# 3. When I am in a breakout room, I lose contact with the main session. So cutoff from the class while in room.

# %% [markdown]
# ##I am going to take some time to try it out
# <img src='https://www.dropbox.com/s/3uyvp722kp5to2r/assignment.png?raw=1' width='300'>
#
# * I am going to assign everyone to break-out rooms randomly, roughly 4 to room.
#
# * Introduce yourselves by audio and maybe draw on a whiteboard.
#
# * Please stay in your room until I join you. You can then go back to main meeting.

# %% [markdown]
# ##Here it goes - rooms and assignments coming
#
# I'm activating the transporter beam.

# %% [markdown]
# #6. I'll record each class
# <img src='https://www.dropbox.com/s/9fcc1crlxp19ijt/major_section.png?raw=1' width='300'>
#
# I'll make these available with a link. I am recording today's class as well :)
#
# I'll also make this notebook available off of canvas.

# %% [markdown]
# #7. Here is what I see
# <img src='https://www.dropbox.com/s/9fcc1crlxp19ijt/major_section.png?raw=1' width='300'>
#
# I took these screenshots with one of my lab researchers (Jason) as a volunteer.

# %% [markdown]
# ##General layout of all the windows
#
# <img src='https://www.dropbox.com/s/cclfzb0lo83sc0q/Screenshot%202020-03-23%2015.12.43.png?raw=1' height=600>
#
# You can see pretty crowded.

# %% [markdown]
# ##Breakout rooms
#
# I placed Jason in Room 1 and he is asking for help. This is what I see.
#
# <img src='https://www.dropbox.com/s/9flem1j0gcpcu1f/Screenshot%202020-03-23%2015.15.09.png?raw=1' height=400>

# %% [markdown]
# ##Me in a room
#
# I don't see a way to communicate or know what is going on in main session :(
#
# <img src='https://www.dropbox.com/s/8y39d8p9h2bzbit/Screenshot%202020-03-23%2015.16.36.png?raw=1' height=300>

# %% [markdown]
# #8. How to set up your screen for lecture piece
# <img src='https://www.dropbox.com/s/9fcc1crlxp19ijt/major_section.png?raw=1' width='300'>
#
# I'm about to switch tabs to the main course content. You have a choice on how to organize yourself. I'll give you the 2 ways I can think of but will take feedback on this whenever you have it.
#
# ##Alternative 1: just watch me.
#
# I am going to be live-coding. This means I'll talk and run code as I go. You can watch and ask questions when you have them.
#
# I suggest you use this alternative for today. You can decide about alternative 2 after that.
#
# ##Alternative 2: live-code along with me.
#
# This is what I would expect in our physical class. I would expect you to download the notebook I will use and then upload it to colab. So you are seeing in your own colab tab what I am sharing on the zoom screen. We both have the same notebook! So when I run some code, you can run the same code in your notebook.
#
# So what's the downside of alternative 2? Screen real-estate for one. You will have to have the zoom window on half the screen and your colab window on other half. Can get kind of crowded on a laptop screen.
#
# The 2nd problem is that if you get an error in your own notebook, it will be difficult to get you help until we break for assignments. I don't see this as a problem, but just sayin.

# %% [markdown]
# #Stop!
# <img src='https://www.dropbox.com/s/kfnmns0f60q8b8z/red_line.png?raw=1' width='300'>
#
# We are about to jump into a new tab with course content.
#
# For those who have not done the download-upload actions for chapter 1, now is time you might want to do it. Go to Announcements on Canvas, find Chapter 1, download notebook to your computer. Upload the notebook to Colab.
#
# I would stick with alternative 1 for the first class until you see how things work. Then you can decide if you want to try alternative 2 later.
